# %% [markdown]
# **DATA FRAME WITH 4 FEATURES AND OBSERVATIONS**

# %%
import numpy as np
import pandas as pd
d_f = pd.DataFrame({'Name':['A','B','C','D'],'Maths':[10,5,6,7],'English':[4,7,9,10],'Computer':[10,8,7,9],'science':[7,6,5,10]})
d_f
# Out:
#   Name  Maths  English  Computer  science
# 0    A     10        4        10        7
# 1    B      5        7         8        6
# 2    C      6        9         7        5
# 3    D      7       10         9       10

# %% [markdown]
# CHANGING COLUMN NAMES

# %%
d_f.columns =['Name','R 1','R 2','R 3','R 4']
d_f
# Out:
#   Name  R 1  R 2  R 3  R 4
# 0    A   10    4   10    7
# 1    B    5    7    8    6
# 2    C    6    9    7    5
# 3    D    7   10    9   10

# %% [markdown]
# ## DESCRIPTIVE STATISTICS

# %%
d_f.describe()
# Out:
#              R 1        R 2        R 3        R 4
# count   4.000000   4.000000   4.000000   4.000000
# mean    7.000000   7.500000   8.500000   7.000000
# std     2.160247   2.645751   1.290994   2.160247
# min     5.000000   4.000000   7.000000   5.000000
# 25%     5.750000   6.250000   7.750000   5.750000
# 50%     6.500000   8.000000   8.500000   6.500000
# 75%     7.750000   9.250000   9.250000   7.750000
# max    10.000000  10.000000  10.000000  10.000000

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
d_f.isnull().any()
# Out:
# Name    False
# R 1     False
# R 2     False
# R 3     False
# R 4     False
# dtype: bool

# %% [markdown]
# # DATA TYPES

# %%
d_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   R 1     4 non-null      int64
#  2   R 2     4 non-null      int64
#  3   R 3     4 non-null      int64
#  4   R 4     4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# # LOCATION AND ILOCATION METHODS

# %%
d_f.loc[:,'R 1':'R 2']
# Out:
#    R 1  R 2
# 0   10    4
# 1    5    7
# 2    6    9
# 3    7   10

# %%
d_f.iloc[:,2:4]
# Out:
#    R 2  R 3
# 0    4   10
# 1    7    8
# 2    9    7
# 3   10    9
